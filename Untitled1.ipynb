# %% [markdown]
# <a href="https://colab.research.google.com/github/darkroot192-sudo/ejercicio-python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio 1
# ###Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print ("¡Hola mundo!")
# Out:
# !Hola mundo!

# %% [markdown]
# ##Ejercicio 2
# ###Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
H= ("¡Hola mundo!")
print (H)
# Out:
# ¡Hola mundo!

# %% [markdown]
# #Ejercicio 3
# ###Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola <nombre>!, donde <nombre> es el nombre que el usuario haya introducido.

# %%
H = input('¿Cual es tu nombre?:')
print ('¡Hola! '+ (H))
# Out:
# ¿Cual es tu nombre?:otoniel
# ¡Hola! otoniel

# %% [markdown]
# #Ejercicio 4
# ###Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética
#  $$\left(\frac{3+2}{2\cdot 5}\right)^2$$

# %%
OA= ((3+2)/(2*5))**2
print(OA)
# Out:
# 0.25

# %% [markdown]
# #Ejercicio 5
# ###Escribir un programa que pregunte al usuario por el número de horas trabajadas y el coste por hora. Después debe mostrar por pantalla la paga que le corresponde.

# %%
horas=int (input('introduce tus horas de trabajo:'))
coste= int(input('introduce cuanto cobras por hora:'))
paga= horas * coste
print ('tu paga es:$'+str (paga))
# Out:
# introduce tus horas de trabajo:585
# introduce cuanto cobras por hora:7898
# tu paga es:$4620330

# %% [markdown]
# #Ejercicio 6
# ###Escribir un programa que lea un entero positivo, $n$,introducido por el usuario y después muestre en pantalla la suma de todos los  enteros desde 1 hasta $n$. La suma de los $n$ primeros enteros positivos puede ser calculada de la siguiente forma:
#  $$\text{suma} = \frac{n(n+1)}{2}$$

# %%
NUM= int(input('ingresa un numero:'))
R = NUM*(NUM+1)/2
print (R)
# Out:
# ingresa un numero:65
# 2145.0

# %% [markdown]
# #Ejercicio 7
# ###Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es <imc> donde <imc> es el índice de masa corporal calculado redondeado con dos decimales.

# %%
KG= int(input('ingresa tu peso en Kg:'))
estatura = float (input('ingresa tu estatura en metros:'))
resultado = KG/(estatura)**2
print (resultado)
# Out:
# ingresa tu peso en Kg:70
# ingresa tu estatura en metros:1.60
# 27.343749999999996

# %% [markdown]
# # Ejercicio 8
# ###Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la `<n> entre <m> da un cociente <c> y un resto <r>` donde `<n>` y `<m>` son los números introducidos por el usuario, y `<c>` y `<r>` son el cociente y el resto de la división entera respectivamente.

# %%
divisor=int(input("ingrese número"))
dividendo=int(input("ingrese número"))
resultado= divisor/dividendo
residuo= round(divisor%dividendo)
print (f"la division entre {divisor} y {dividendo} da un resultado de {resultado} con residuo de {residuo}")
# Out:
# ingrese número5
# ingrese número2
# la division entre 5 y 2 da un resultado de 2.5 con residuo de 1

# %% [markdown]
# #Ejercicio 9
# ###Escribir un programa que pregunte al usuario una cantidad a invertir, el interés anual y el número de años, y muestre por pantalla el capital obtenido en la inversión.

# %%
inversion=int(input("¿que cantidad desea invertir?"))
interes=float(input("cual es el interes anual que desea obtener?"))
años=int(input("¿a cuantos años?"))
ganancia= (inversion*interes*años)

print("tu ganancia es de:",ganancia)
# Out:
# ¿que cantidad desea invertir?1000
# cual es el interes anual que desea obtener?.05
# ¿a cuantos años?2
# tu ganancia es de: 100.0

# %% [markdown]
# #Ejercicio 10
# ###
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %%
peso_payasos=float(.112)
peso_muñecas=float(.75)
payasos= int (input("ingrese total de payasos vendidos en el ultimo pedido:"))
muñecas=  int (input("ingrese total de muñecas vendidasen el ultimo pedido:"))
totalpesos= (peso_payasos*payasos + peso_muñecas*muñecas)
print("el peso total del paquete es de",totalpesos,ç"kg")
# Out:
# ingrese total de payasos vendidos en el ultimo pedido:10
# ingrese total de muñecas vendidasen el ultimo pedido:7
# el peso total del paquete es de 6.37 kg
